# %%
import pandas as pd
import matplotlib.pyplot as plt
 
df=pd.read_csv("unicorntable_india.csv")
df
# Out:
#      No.             Company                                  Sector  \
# 0      1              InMobi                     Adtech - Mobile Ads
# 1      2            Flipkart                              E-Commerce
# 2      3            Mu Sigma                        SaaS - Analytics
# 3      4            Snapdeal                              E-Commerce
# 4      5               PayTM             Fintech - Payments & Wallet
# ..   ...                 ...                                     ...
# 97    98             Purplle  E-Commerce - Personal Care & Cosmetics
# 98    99         Leadsquared                              SaaS - CRM
# 99   100             OneCard                  Fintech - Credit Cards
# 100  101          Shiprocket         Aggregator - Logistics Services
# 101  102  Molbio Diagnostics                Healthtech - Diagnostics
#
#      Publicly Listed   Entry Valuation($B)  Valuation ($B)   Entry  \
# 0                   0                 1.00            1.00  11-Sep
# ...

# %%
df.head(5)
# Out:
#    No.   Company                       Sector  Publicly Listed   \
# 0    1    InMobi          Adtech - Mobile Ads                 0
# 1    2  Flipkart                   E-Commerce                 1
# 2    3  Mu Sigma             SaaS - Analytics                 0
# 3    4  Snapdeal                   E-Commerce                 0
# 4    5     PayTM  Fintech - Payments & Wallet                 1
#
#    Entry Valuation($B)  Valuation ($B)   Entry  Formar Unicorn  \
# 0                  1.0             1.0  11-Sep               0
# 1                  1.0            37.6  12-Feb               0
# 2                  1.0             1.5  13-Feb               0
# 3                  1.8             2.4  14-Oct               1
# 4                  1.7            16.0  15-Feb               0
#
#               Location                                   Select Investors
# 0  Bangalore/Singapore                  KPCB, Sherpalo Ventures, SoftBank
# ...

# %%
df.loc[1]
# Out:
# No.                                                                  2
# Company                                                       Flipkart
# Sector                                                      E-Commerce
# Publicly Listed                                                      1
# Entry Valuation($B)                                                1.0
# Valuation ($B)                                                    37.6
# Entry                                                           12-Feb
# Formar Unicorn                                                       0
# Location                                           Bangalore/Singapore
# Select Investors       Accel, Tiger Global, Naspers, SoftBank, Tencent
# Name: 1, dtype: object

# %%
len(df)
# Out:
# 102

# %%
df.head()
# Out:
#    No.   Company                       Sector  Publicly Listed   \
# 0    1    InMobi          Adtech - Mobile Ads                 0
# 1    2  Flipkart                   E-Commerce                 1
# 2    3  Mu Sigma             SaaS - Analytics                 0
# 3    4  Snapdeal                   E-Commerce                 0
# 4    5     PayTM  Fintech - Payments & Wallet                 1
#
#    Entry Valuation($B)  Valuation ($B)   Entry  Formar Unicorn  \
# 0                  1.0             1.0  11-Sep               0
# 1                  1.0            37.6  12-Feb               0
# 2                  1.0             1.5  13-Feb               0
# 3                  1.8             2.4  14-Oct               1
# 4                  1.7            16.0  15-Feb               0
#
#               Location                                   Select Investors
# 0  Bangalore/Singapore                  KPCB, Sherpalo Ventures, SoftBank
# ...

# %%
df.tail(2)
# Out:
#      No.             Company                           Sector  \
# 100  101          Shiprocket  Aggregator - Logistics Services
# 101  102  Molbio Diagnostics         Healthtech - Diagnostics
#
#      Publicly Listed   Entry Valuation($B)  Valuation ($B)   Entry  \
# 100                 0                 1.23            1.23  22-Aug
# 101                 0                 1.53            1.53  22-Sep
#
#      Formar Unicorn Location  \
# 100               0    Delhi
# 101               0      Goa
#
#                                       Select Investors
# 100  Lightrock India, Info Edge, Tribe Capital, Tem...
# 101                             Temasek, Motilal Oswal

# %%
df.Sector
# Out:
# 0                         Adtech - Mobile Ads
# 1                                  E-Commerce
# 2                            SaaS - Analytics
# 3                                  E-Commerce
# 4                 Fintech - Payments & Wallet
#                         ...
# 97     E-Commerce - Personal Care & Cosmetics
# 98                                 SaaS - CRM
# 99                     Fintech - Credit Cards
# 100           Aggregator - Logistics Services
# 101                  Healthtech - Diagnostics
# Name: Sector, Length: 102, dtype: object

# %%
df.Sector	.head()
# Out:
# 0            Adtech - Mobile Ads
# 1                     E-Commerce
# 2               SaaS - Analytics
# 3                     E-Commerce
# 4    Fintech - Payments & Wallet
# Name: Sector, dtype: object

# %%
 df.columns
# Out:
# Index(['No.', 'Company', 'Sector', 'Publicly Listed ', 'Entry Valuation($B)',
#        'Valuation ($B)', 'Entry', 'Formar Unicorn', 'Location',
#        'Select Investors'],
#       dtype='object')

# %%
df.columns[2]
# Out:
# 'Sector'

# %%
df.loc[[0,3,5]]
# Out:
#    No.   Company                      Sector  Publicly Listed   \
# 0    1    InMobi         Adtech - Mobile Ads                 0
# 3    4  Snapdeal                  E-Commerce                 0
# 5    6  Ola Cabs  Mobility - Ride Aggregator                 0
#
#    Entry Valuation($B)  Valuation ($B)   Entry  Formar Unicorn  \
# 0                  1.0             1.0  11-Sep               0
# 3                  1.8             2.4  14-Oct               1
# 5                  1.6             7.3  15-Mar               0
#
#               Location                                   Select Investors
# 0  Bangalore/Singapore                  KPCB, Sherpalo Ventures, SoftBank
# 3                Delhi  Kalaari Capital, Nexus Ventures, Bessemer, Sof...
# 5            Bangalore  Tiger Global, Matrix Partners, Steadview, Soft...
